# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
from scipy.stats import binom
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('king_county.csv')

data = data['floors']

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    floors
# 0     1.0
# 1     2.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
df.describe()
# Out:
#              floors
# count  21613.000000
# mean       1.494309
# std        0.539989
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.000000
# max        3.500000

# %%
df.plot(kind="density",  # Plot the distribution
                               figsize=(5,5),
                               xlim=(-1,11))
# Out:
# <Axes: ylabel='Density'>

# %%
sns.countplot(x="floors", data=df)
# Out:
# <Axes: xlabel='floors', ylabel='count'>

# %%
import scipy.stats as stats

x = 80
cdf_value =  stats.norm.cdf(x,loc=76,scale=2.5)
cdf_value

print(f'Probability of obtaining a value LESS THAN or equal to: {x} is {cdf_value}')
# Out:
# Probability of obtaining a value LESS THAN or equal to: 80 is 0.945200708300442

# %%
x = 80
cdf_value = 1 - stats.norm.cdf(x,loc=76,scale=2.5)
cdf_value
# Out:
# 0.054799291699557995

# %%
stats.norm.cdf(9410, 2080, 918)
# Out:
# 0.9999999999999993

# %%
prob_under_minus1 = stats.norm.cdf(x= -1, loc= 1789, scale=829)
prob_above_minus1  =stats.norm.cdf(x= 1, loc= 1789, scale=829)

prob_over_1 = 1 - prob_above_minus1

between_prob = 1-(prob_under_minus1+prob_over_1)

print(prob_under_minus1, prob_above_minus1, prob_over_1, between_prob)
# Out:
# 0.015416241963140937 0.015510023788748346 0.9844899762112517 9.378182560737525e-05

# %%
import numpy as np
# Plot normal distribution areas*

plt.rcParams["figure.figsize"] = (10,8)

plt.fill_between(x=np.arange(-4,-1,0.01),
                 y1= stats.norm.pdf(np.arange(-4,-1,0.01)) ,
                 facecolor='red',
                 alpha=0.5)

plt.fill_between(x=np.arange(1,4,0.01),
                 y1= stats.norm.pdf(np.arange(1,4,0.01)) ,
                 facecolor='red',
                 alpha=0.5)

plt.fill_between(x=np.arange(-1,1,0.01),
                 y1= stats.norm.pdf(np.arange(-1,1,0.01)) ,
                 facecolor='blue',
                 alpha=0.35)

plt.text(x=-1.8, y=0.03, s= round(prob_under_minus1,3))
plt.text(x=-0.2, y=0.1, s= round(between_prob,3))
plt.text(x=1.4, y=0.03, s= round(prob_over_1,3));

# %%
plt.rcParams["figure.figsize"] = (5,3)

plt.fill_between(x=np.arange(-4,-1,0.01),
                 y1= stats.norm.pdf(np.arange(-4,-1,0.01)) ,
                 facecolor='red',
                 alpha=0.55)

plt.fill_between(x=np.arange(1,4,0.01),
                 y1= stats.norm.pdf(np.arange(1,4,0.01)) ,
                 facecolor='red',
                 alpha=0.55)

plt.fill_between(x=np.arange(-1,1,0.01),
                 y1= stats.norm.pdf(np.arange(-1,1,0.01)) ,
                 facecolor='blue',
                 alpha=0.55)

plt.text(x=-1.8, y=0.03, s= round(prob_under_minus1,3))
plt.text(x=-0.2, y=0.1, s= round(between_prob,3))
plt.text(x=1.4, y=0.03, s= round(prob_over_1,3))
# Out:
# Text(1.4, 0.03, '0.984')

# %%
pd.DataFrame(df).hist(range=(-0.5,3), bins=11)
# Out:
# array([[<Axes: title={'center': 'floors'}>]], dtype=object)

# %%
stats.binom.cdf(k=5,        # Probability of k = 5 successes or less
                n=10,       # With 10 flips
                p=0.8)      # And success probability 0.8
# Out:
# 0.03279349759999997

# %%
stats.poisson.cdf(k=829,     # Check the probability of 5 arrivals or less
                  mu=1789)   # With arrival rate 10
# Out:
# 2.6369576224920547e-142

# %%
pd.DataFrame(df["floors"]).hist(range=(-0.5,max(df["floors"])+0.5)
                                    ,bins=max(df["floors"])+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Hamza\anaconda3\lib\site-packages\numpy\lib\histograms.py:419, in _get_bin_edges(a, bins, range, weights)
#     418 try:
# --> 419     n_equal_bins = operator.index(bins)
#     420 except TypeError as e:
#
# TypeError: 'float' object cannot be interpreted as an integer
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 pd.DataFrame(df["floors"]).hist(range=(-0.5,max(df["floors"])+0.5)
#       2                                     ,bins=max(df["floors"])+1)
#
# File c:\Users\Hamza\anaconda3\lib\site-packages\pandas\plotting\_core.py:226, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
# ...

# %%
fig, ax = plt.subplots()

sns.histplot(df["floors"], ax = ax, bins=25)
ax.set_xlim(0, 2)
ax.set_xticks(range(-1,4))
plt.show()
